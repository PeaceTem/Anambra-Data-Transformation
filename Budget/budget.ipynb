# %%
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

# %%
sheets = ["Sheet1"]
file_names = ["./data/budget_2022.xlsx", "./data/budget_2023.xlsx", "./data/budget_2024.xlsx", "./data/budget_2025.xlsx"]
years = [2022, 2023, 2024, 2025]
dfs = []
for index, file_name in enumerate(file_names):
    dfs.append(pd.read_excel(file_name, sheet_name="Sheet1"))

# %%
for index, df in enumerate(dfs):
    dfs[index] = dfs[index].fillna(0)
    dfs[index].replace(['NA', 'NIL', '-'], 0, inplace=True)

dfs[0].head()
# Out:
#                                           Ministry  Personnel Cost  \
# 0                 Office of the Executive Governor    643829526.50
# 1  Office of the Secretary to the State Government    462472582.30
# 2                              Ministry of Finance    318861189.20
# 3                                Ministry of Works    185899318.20
# 4                          Ministry of Environment    269336206.80
#
#    Overhead Cost  Recurrent Expenditure  Capital Expenditure  \
# 0 28607825825.00         36643366813.00           9000000000
# 1   621054701.00          1062501318.00           2546000000
# 2    22812946.48           341674135.70           6025500000
# 3    32427354.55           228326672.80         263320000000
# 4    77971382.08           261088351.70                    0
#
#    Total Expenditure
# 0     45643366813.00
# 1      3658501318.00
# 2      6365174136.00
# 3    266713266673.00
# 4       261088351.70

# %%
# columns = ['Ministry', 'Personnel Cost', 'Overhead Cost', 'response']

new_df = pd.DataFrame(columns=["year", *dfs[0].columns])

for i, df in enumerate(dfs):
    year = years[i]
    df["year"] = year
    
    new_df = pd.concat([new_df, df], ignore_index=True)


new_df.head(50)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4572\2758193881.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_df = pd.concat([new_df, df], ignore_index=True)
#     year                                           Ministry  Personnel Cost  \
# 0   2022                   Office of the Executive Governor    643829526.50
# 1   2022    Office of the Secretary to the State Government    462472582.30
# 2   2022                                Ministry of Finance    318861189.20
# 3   2022                                  Ministry of Works    185899318.20
# 4   2022                            Ministry of Environment    269336206.80
# 5   2022                                Ministry of Justice    573367392.20
# 6   2022       Ministry of Culture, Entertainment & Tourism    110066559.50
# 7   2022        Ministry of Petroleum and Mineral Resources    101311864.00
# 8   2022  Ministry of Local Government, Chieftaincy & Co...    677308192.60
# 9   2022                Ministry of Power & Water Resources    488275684.10
# 10  2022                         Ministry of Special Duties     20572200.00
# 11  2022                    Anambra State House of Assembly   1519128693.00
# 12  2022     Anambra State Independent Electoral Commission     67113487.50
# 13  2022                        Judicial Service Commission   5683750263.00
# 14  2022             Anambra State Internal Revenue Service    525015287.40
# 15  2022                            Ministry of Information    273066530.20
# 16  2022                      Office of the Head of Service   1026410186.00
# 17  2022  Anambra State Investment Promotion & Protectio...    201583990.00
# 18  2022                   Christian Pilgrims Welfare Board      6976500.00
# 19  2022                      Muslim Pilgrims Welfare Board      6910350.00
# 20  2022                       Ministry of Homeland Affairs    131779993.10
# 21  2022  Ministry of Social Welfare, Children & Women A...    110446652.80
# 22  2022                                Ministry of Housing    134600177.30
# 23  2022                               Ministry of Industry    270883462.60
# 24  2022             Ministry of Budget & Economic Planning    178035997.80
# 25  2022                              Ministry of Transport    241024782.20
# 26  2022                            Ministry of Agriculture    608826114.30
# 27  2022                              Ministry of Education    312935929.10
# 28  2022                                 Ministry of Youths    147732064.20
# 29  2022                                 Ministry of Health    518449487.80
# 30  2022                                  Ministry of Lands    258238168.20
# 31  2023                   Office of the Executive Governor    659829526.50
# 32  2023    Office of the Secretary to the State Government    479472582.30
# 33  2023                                Ministry of Finance    329861189.20
# 34  2023                                  Ministry of Works    195899318.20
# 35  2023                            Ministry of Environment    275336206.80
# 36  2023                                Ministry of Justice    593367392.20
# 37  2023       Ministry of Culture, Entertainment & Tourism    115066559.50
# 38  2023        Ministry of Petroleum and Mineral Resources    105311864.00
# 39  2023  Ministry of Local Government, Chieftaincy & Co...    687308192.60
# 40  2023                Ministry of Power & Water Resources    498275684.10
# 41  2023                         Ministry of Special Duties     21572200.00
# 42  2023                    Anambra State House of Assembly   1539128693.00
# 43  2023     Anambra State Independent Electoral Commission     68113487.50
# 44  2023                        Judicial Service Commission   5783750263.00
# 45  2023             Anambra State Internal Revenue Service    545015287.40
# 46  2023                            Ministry of Information    283066530.20
# 47  2023                      Office of the Head of Service   1046410186.00
# 48  2023  Anambra State Investment Promotion & Protectio...    211583990.00
# 49  2023                   Christian Pilgrims Welfare Board      7076500.00
#
#     Overhead Cost  Recurrent Expenditure Capital Expenditure  \
# 0  28607825825.00         36643366813.00          9000000000
# 1    621054701.00          1062501318.00          2546000000
# 2     22812946.48           341674135.70          6025500000
# 3     32427354.55           228326672.80        263320000000
# 4     77971382.08           261088351.70                   0
# 5     18339716.08           611057108.30          3065000000
# 6     11384103.65           113450663.10         10111000000
# 7     12984967.33           107296831.30           379000000
# 8            0.00           677308192.60                   0
# 9     16705378.60           413892105.20         13846833333
# 10    17227600.00            39799800.00           915000000
# 11  3045100261.00          4604228954.00          5858000000
# 12    16910052.69            88023540.19           165000000
# 13    71849237.68          5862263617.00          7785600000
# 14    89712371.74           634727659.10           679000000
# 15    17211374.00           292277904.20          5243118000
# 16   275920722.10          1302330908.00           846000000
# 17           0.00           201583990.00                   0
# 18           0.00             6976500.00                   0
# 19           0.00             6910350.00                   0
# 20    13107400.00           140887393.10          2601500000
# 21     9351322.00           120197974.80          2570600000
# 22    11860000.00           148460177.30          9995000000
# 23    19656250.00           292539712.60           527000000
# 24    57476821.46           239512819.30          3411000000
# 25    11860000.00           254884782.20          3279700000
# 26    66476821.46           626970954.30          2676000000
# 27   797764026.20          1130699955.00         36374500000
# 28    15822177.10           161554241.30          3204000000
# 29           0.00           518449487.80                   0
# 30    18182554.00           278420722.20          1669000000
# 31 29607825825.00         36643366813.00          9200000000
# 32   641054701.00          1062501318.00          2646000000
# 33    23812946.48           353674135.70          6125500000
# 34    33427354.55           239326672.80        265320000000
# 35    87971382.08           273088351.70                   0
# 36    19339716.08           621057108.30          3095000000
# 37    12384103.65           123450663.10         10211000000
# 38    13984967.33           117296831.30           389000000
# 39           0.00           687308192.60                   0
# 40    17705378.60           423892105.20         14046833333
# 41    18227600.00            40799800.00           925000000
# 42  3145100261.00          4704228954.00          5958000000
# 43    17910052.69            89023540.19           175000000
# 44    81849237.68          5962263617.00          7885600000
# 45    99712371.74           654727659.10           689000000
# 46    18211374.00           302277904.20          5343118000
# 47   285920722.10          1332330908.00           856000000
# 48           0.00           211583990.00                   0
# 49           0.00             7076500.00                   0
#
#     Total Expenditure
# 0      45643366813.00
# 1       3658501318.00
# 2       6365174136.00
# 3     266713266673.00
# 4        261088351.70
# 5       3688707108.00
# 6      10224450663.00
# 7        486296831.30
# 8        677308192.60
# 9      18285743337.00
# 10       936799800.00
# 11     10462228954.00
# 12       253523540.20
# 13     13657863617.00
# 14      1313727659.00
# 15      5515395904.00
# 16      2148330908.00
# 17       201583990.00
# 18         6976500.00
# 19         6910350.00
# 20      2752387393.00
# 21      2902226775.00
# 22     10199650177.00
# 23       819093412.60
# 24       580612819.30
# 25      3554814782.00
# 26       894570954.30
# 27     47781499955.00
# 28       471954241.30
# 29       518449487.80
# 30       445320722.20
# 31     45843366813.00
# 32      3708501318.00
# 33      6475174136.00
# 34    268713266673.00
# 35       273088351.70
# 36      3708707108.00
# 37     10334450663.00
# 38       506296831.30
# 39       687308192.60
# 40     18485743337.00
# 41       953799800.00
# 42     10662228954.00
# 43       264523540.20
# 44     13857863617.00
# 45      1343727659.00
# 46      5625395904.00
# 47      2188330908.00
# 48       211583990.00
# 49         7076500.00

# %%
print(len(new_df))
# Out:
# 124

# %%
new_df.to_excel("transposed/budget.xlsx", index=False)
print("Finished!")
# Out:
# Finished!

# %%
import pandas as pd
pd.options.display.float_format = '{:.0f}'.format

# %%
sheets = ["Sheet1"]
file_names = ["./data/budget_2022.xlsx", "./data/budget_2023.xlsx", "./data/budget_2024.xlsx", "./data/budget_2025.xlsx"]
years = [2022, 2023, 2024, 2025]
dfs = []
for index, file_name in enumerate(file_names):
    dfs.append(pd.read_excel(file_name, sheet_name="Sheet1"))

# %%
for index, df in enumerate(dfs):
    dfs[index] = dfs[index].fillna(0)
    dfs[index].replace(['NA', 'NIL', '-'], 0, inplace=True)

dfs[0].head()
# Out:
#                                           Ministry  Personnel Cost  \
# 0                 Office of the Executive Governor       643829526
# 1  Office of the Secretary to the State Government       462472582
# 2                              Ministry of Finance       318861189
# 3                                Ministry of Works       185899318
# 4                          Ministry of Environment       269336207
#
#    Overhead Cost  Recurrent Expenditure  Capital Expenditure  \
# 0    28607825825            36643366813           9000000000
# 1      621054701             1062501318           2546000000
# 2       22812946              341674136           6025500000
# 3       32427355              228326673         263320000000
# 4       77971382              261088352                    0
#
#    Total Expenditure
# 0        45643366813
# 1         3658501318
# 2         6365174136
# 3       266713266673
# 4          261088352

# %%
# columns = ['Ministry', 'Personnel Cost', 'Overhead Cost', 'response']

new_df = pd.DataFrame(columns=["year", *dfs[0].columns])

for i, df in enumerate(dfs):
    year = years[i]
    df["year"] = year
    
    new_df = pd.concat([new_df, df], ignore_index=True)


new_df.head(50)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9920\2758193881.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_df = pd.concat([new_df, df], ignore_index=True)
#     year                                           Ministry  Personnel Cost  \
# 0   2022                   Office of the Executive Governor       643829526
# 1   2022    Office of the Secretary to the State Government       462472582
# 2   2022                                Ministry of Finance       318861189
# 3   2022                                  Ministry of Works       185899318
# 4   2022                            Ministry of Environment       269336207
# 5   2022                                Ministry of Justice       573367392
# ...

# %%
print(len(new_df))
# Out:
# 124

# %%
new_df.to_excel("transposed/budget.xlsx", index=False)
print("Finished!")
# Out:
# Finished!

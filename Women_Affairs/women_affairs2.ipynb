# %%
import pandas as pd

# %%
sheets = ["Sheet1"]
file_names = ["women_affairs.xlsx"]
years = [2024]
dfs = []
for index, file_name in enumerate(file_names):
    dfs.append(pd.read_excel(file_name, sheet_name="Sheet1"))

lga_df = pd.read_csv("../Geography/Anambra_LGAs.csv")
lga_df.head()
# Out:
#    lga_id       lga_name     zone  AREA_SQ_KM  HIGHLANDS_percent  \
# 0       1  ONITSHA SOUTH  ONITSHA         196                 20
# 1       2   ANAMBRA WEST  OTUOCHA         613                 15
# 2       3  IDEMILI SOUTH    OGIDI         145                 20
# 3       4    NNEWI SOUTH    NNEWI         176                 34
# 4       5            OYI    OGIDI         331                 10
#
#    PLAIN_LANDS_percent
# 0                   48
# 1                   21
# 2                   25
# 3                   38
# 4                   40

# %%
# for index, df in enumerate(dfs):
#     dfs[index] = dfs[index].fillna(0)
#     dfs[index].replace(['NA', 'NIL', '-'], 0, inplace=True)

dfs[0].head()
# Out:
#    S/N PHYSICAL ABUSE/BATTERY PSYCHOLOGICAL/EMOTIONAL ABUSE SEXUAL ASSAULT  \
# 0    1                    NaN                           NaN            NaN
# 1    2                    NaN                           NaN            YES
# 2    3                    YES                           NaN            NaN
# 3    4                    YES                           NaN            NaN
# 4    5                    NaN                           NaN            NaN
#
#   RAPE/DEFILEMENT FEMALE GENITAL MUTILATION FORCED MARRIAGE  \
# 0             NaN                       NaN             NaN
# 1             NaN                       NaN             NaN
# 2             NaN                       NaN             NaN
# 3             NaN                       NaN             NaN
# 4             NaN                       NaN             NaN
#
#   CHILD ABUSE AND NEGLECT  TRAFFICKING IN PERSONS  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#   FORCEFUL EJECTION FROM FAMILY  ...       EDUCATION LEVEL  \
# 0                           NaN  ...  COMPLETED SEC SCHOOL
# 1                           NaN  ...       SOME SEC SCHOOL
# 2                           NaN  ...              GRADUATE
# 3                           NaN  ...  COMPLETED SEC SCHOOL
# 4                           NaN  ...  COMPLETED SEC SCHOOL
#
#   ALLEGED PERPETRATOR SEX ACCESS TO JUSTICE CASE CLOSED CASE CLOSED BY  \
# 0                       M               YES          NO            NaN
# 1                       M               YES          NO            NaN
# 2                     NaN               YES          NO            NaN
# 3                     M,F               YES          NO            NaN
# 4                       M               YES          NO            NaN
#
#   DATE CASE CLOSED FINAL OUTCOME DATE JUSTICE DELIVERED Unnamed: 29 STATE
# 0              NaT           NaN                    NaT         NaN   NaN
# 1              NaT           NaN                    NaT         NaN   NaN
# 2              NaT           NaN                    NaT         NaN   NaN
# 3              NaT           NaN                    NaT         NaN   NaN
# 4              NaT           NaN                    NaT         NaN   NaN
#
# [5 rows x 31 columns]

# %%
columns = ['sn', 'year', 'question', 'response']

new_df = pd.DataFrame(columns=columns)
year = 2024

for i, df in enumerate(dfs):
    for index, row in df.iterrows():
        for col in df.columns[1:]:
            # if(row[col] in ('0', 0)): continue
            transformed_data = [{
                'sn': row["S/N"],
                'year': year,
                'question': col,
                'response': row[col],
            }]

            new_df = pd.concat([new_df, pd.DataFrame(transformed_data)], ignore_index=True)


new_df.head(50)
# Out:
#    sn  year                                     question              response
# 0   1  2024                       PHYSICAL ABUSE/BATTERY                   NaN
# 1   1  2024                PSYCHOLOGICAL/EMOTIONAL ABUSE                   NaN
# 2   1  2024                               SEXUAL ASSAULT                   NaN
# 3   1  2024                              RAPE/DEFILEMENT                   NaN
# 4   1  2024                    FEMALE GENITAL MUTILATION                   NaN
# 5   1  2024                              FORCED MARRIAGE                   NaN
# 6   1  2024                      CHILD ABUSE AND NEGLECT                   NaN
# 7   1  2024                       TRAFFICKING IN PERSONS                   NaN
# 8   1  2024                FORCEFUL EJECTION FROM FAMILY                   NaN
# 9   1  2024  FORCEFUL SEPARATION OF CHILDREN FROM MOTHER                   NaN
# 10  1  2024    VIOLATION OF PROPERTY & INHERITANCE RIGHT                   YES
# 11  1  2024                          DENIAL OF RESOURCES                   NaN
# 12  1  2024                     FINANCIAL/ECONOMIC ABUSE                   YES
# 13  1  2024                                          LGA               ANAOCHA
# 14  1  2024                                         WARD           AGULUZOIGBO
# 15  1  2024                             DATE OF INCIDENT   2022-11-16 00:00:00
# 16  1  2024                                DATE REPORTED   2024-02-12 00:00:00
# 17  1  2024                                   VICTIM SEX                     F
# 18  1  2024                               MARITAL STATUS               MARRIED
# 19  1  2024                                EMPLOY STATUS          SELF EMPOYED
# 20  1  2024                              EDUCATION LEVEL  COMPLETED SEC SCHOOL
# 21  1  2024                      ALLEGED PERPETRATOR SEX                     M
# 22  1  2024                            ACCESS TO JUSTICE                   YES
# 23  1  2024                                  CASE CLOSED                    NO
# 24  1  2024                               CASE CLOSED BY                   NaN
# 25  1  2024                             DATE CASE CLOSED                   NaN
# 26  1  2024                                FINAL OUTCOME                   NaN
# 27  1  2024                       DATE JUSTICE DELIVERED                   NaN
# 28  1  2024                                  Unnamed: 29                   NaN
# 29  1  2024                                        STATE                   NaN
# 30  2  2024                       PHYSICAL ABUSE/BATTERY                   NaN
# 31  2  2024                PSYCHOLOGICAL/EMOTIONAL ABUSE                   NaN
# 32  2  2024                               SEXUAL ASSAULT                   YES
# 33  2  2024                              RAPE/DEFILEMENT                   NaN
# 34  2  2024                    FEMALE GENITAL MUTILATION                   NaN
# 35  2  2024                              FORCED MARRIAGE                   NaN
# 36  2  2024                      CHILD ABUSE AND NEGLECT                   NaN
# 37  2  2024                       TRAFFICKING IN PERSONS                   NaN
# 38  2  2024                FORCEFUL EJECTION FROM FAMILY                   NaN
# 39  2  2024  FORCEFUL SEPARATION OF CHILDREN FROM MOTHER                   NaN
# 40  2  2024    VIOLATION OF PROPERTY & INHERITANCE RIGHT                   NaN
# 41  2  2024                          DENIAL OF RESOURCES                   NaN
# 42  2  2024                     FINANCIAL/ECONOMIC ABUSE                   NaN
# 43  2  2024                                          LGA                AGUATA
# 44  2  2024                                         WARD             UJUALIGWE
# 45  2  2024                             DATE OF INCIDENT   2024-01-01 00:00:00
# 46  2  2024                                DATE REPORTED   2024-03-13 00:00:00
# 47  2  2024                                   VICTIM SEX                   NaN
# 48  2  2024                               MARITAL STATUS               MARRIED
# 49  2  2024                                EMPLOY STATUS          SELF EMPOYED

# %%
print(len(new_df))
# Out:
# 22740

# %%
new_df.to_excel("Women_affairs_transposed.xlsx", index=False)
print("Done!")
# Out:
# Done!

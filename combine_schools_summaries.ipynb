# %%
import pandas as pd

# %%
pry_df = pd.read_csv("Primary_Schools_Summaries.csv")
sec_df = pd.read_excel("new_school_population.xlsx", sheet_name="SCHOOL SUMMARIES")

# %%
df = pd.concat([sec_df, pry_df], ignore_index=True)
df.head()
# Out:
#    school_id class   timestamp gender  population
# 0          1  JSS1  12-01-2023   Male           0
# 1          1  JSS2  12-01-2023   Male           0
# 2          1  JSS3  12-01-2023   Male           0
# 3          1  SSS1  12-01-2023   Male           0
# 4          1  SSS2  12-01-2023   Male           0

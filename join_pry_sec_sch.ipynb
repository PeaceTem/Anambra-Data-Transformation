# %%
import pandas as pd

# %%
pry_df = pd.read_csv("Primary_Schools.csv")
pry_df.head()
# Out:
#    lga_id  school_id                    school_name     school_type category  \
# 0      13       2001          CENTRAL SCHOOL ACHINA  PUBLIC MISSION  Primary
# 1      13       2002      PRIMARY SCHOOL EKE ACHINA  PUBLIC MISSION  Primary
# 2      13       2003         OBINIKPA SCHOOL ACHINA  PUBLIC MISSION  Primary
# 3      13       2004      PROGRESSIVE SCHOOL ACHINA  PUBLIC MISSION  Primary
# 4      13       2005  CENTRAL SCHOOL AGULUEZECHUKWU  PUBLIC MISSION  Primary
#
#    lat  long
# 0  NaN   NaN
# 1  NaN   NaN
# 2  NaN   NaN
# 3  NaN   NaN
# 4  NaN   NaN

# %%
sec_df = pd.read_csv("Secondary_Schools.csv")
sec_df.head()
# Out:
#    lga_id  school_id                         school_name school_type  \
# 0      13          1              AGUATA HIGH SCH.AGUATA      PUBLIC
# 1      13          2  CHRIST THE REDEEMER COLLEGE  AMESI      PUBLIC
# 2      13          3      COMM SEC. SCH. (BSS) EZINIFITE      PUBLIC
# 3      13          4       COMM SEC. SCH. (BSS) IGBOUKWU      PUBLIC
# 4      13          5       COMM SEC. SCH. AGULUEZECHUKWU      PUBLIC
#
#     category  lat  long
# 0  Secondary  NaN   NaN
# 1  Secondary  NaN   NaN
# 2  Secondary  NaN   NaN
# 3  Secondary  NaN   NaN
# 4  Secondary  NaN   NaN

# %%
new_df = pd.concat([sec_df, pry_df], ignore_index=True)
new_df.head(1500)
# Out:
#       lga_id  school_id                                  school_name  \
# 0         13          1                       AGUATA HIGH SCH.AGUATA
# 1         13          2           CHRIST THE REDEEMER COLLEGE  AMESI
# 2         13          3               COMM SEC. SCH. (BSS) EZINIFITE
# 3         13          4                COMM SEC. SCH. (BSS) IGBOUKWU
# 4         13          5                COMM SEC. SCH. AGULUEZECHUKWU
# ...      ...        ...                                          ...
# 1495       8       2460              CHUKE MEMORIAL . PRIMARY  OBOSI
# 1496       8       2461           OKPUNO UMUOTA PRIMARY SXCHOOLOBOSI
# 1497       8       2462  GBUGHOBI MEMORIAL . CENTRAL . SCHOOL. OBOSI
# 1498       8       2463               COMMUNITY PRIMARY UGAMUMA OBOS
# 1499       8       2464                    IRE CENTRAL  SCHOOL OBOSI
#
#          school_type   category  lat  long
# 0             PUBLIC  Secondary  NaN   NaN
# 1             PUBLIC  Secondary  NaN   NaN
# ...

# %%
new_df.head(1500)
# Out:
#       lga_id  school_id                                  school_name  \
# 0         13          1                       AGUATA HIGH SCH.AGUATA
# 1         13          2           CHRIST THE REDEEMER COLLEGE  AMESI
# 2         13          3               COMM SEC. SCH. (BSS) EZINIFITE
# 3         13          4                COMM SEC. SCH. (BSS) IGBOUKWU
# 4         13          5                COMM SEC. SCH. AGULUEZECHUKWU
# ...      ...        ...                                          ...
# 1495       8       2460              CHUKE MEMORIAL . PRIMARY  OBOSI
# 1496       8       2461           OKPUNO UMUOTA PRIMARY SXCHOOLOBOSI
# 1497       8       2462  GBUGHOBI MEMORIAL . CENTRAL . SCHOOL. OBOSI
# 1498       8       2463               COMMUNITY PRIMARY UGAMUMA OBOS
# 1499       8       2464                    IRE CENTRAL  SCHOOL OBOSI
#
#          school_type   category  lat  long
# 0             PUBLIC  Secondary  NaN   NaN
# 1             PUBLIC  Secondary  NaN   NaN
# ...

# %%
new_df.to_csv("combine_schools.csv", index=False)
print("Done!")
# Out:
# Done!

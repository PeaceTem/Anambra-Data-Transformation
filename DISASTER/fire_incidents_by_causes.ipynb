# %%
import pandas as pd

# %%
years = [2022]
sheets = ["Table 129"]
dfs = []
for index, sheet in enumerate(sheets):
    dfs.append(pd.read_excel("../AGRICULTURE/anambra_2022_year_book.xlsx", sheet_name=sheets[index]))

lga_df = pd.read_csv("../Geography/Anambra_LGAs.csv")
lga_df.head()
# Out:
#    lga_id       lga_name     zone  AREA_SQ_KM  HIGHLANDS_percent  \
# 0       1  ONITSHA SOUTH  ONITSHA         196                 20
# 1       2   ANAMBRA WEST  OTUOCHA         613                 15
# 2       3  IDEMILI SOUTH    OGIDI         145                 20
# 3       4    NNEWI SOUTH    NNEWI         176                 34
# 4       5            OYI    OGIDI         331                 10
#
#    PLAIN_LANDS_percent
# 0                   48
# 1                   21
# 2                   25
# 3                   38
# 4                   40

# %%
for index, df in enumerate(dfs):
    dfs[index] = dfs[index].fillna(0)
    dfs[index].replace(['NA', 'NIL', '-'], 0, inplace=True)

dfs[0].head()
# Out:
#         CAUSE OF FIRE INCIDENCE  NUMBER OF FIRE INCIDENTS  \
# 0          ELECTRICAL EQUIPMENT                         1
# 1                        CANDLE                         1
# 2        HIGH VOLTAGE FROM EEDC                         1
# 3               CIGARETTE STUBS                         1
# 4  ILLEGAL STORAGE OF PETROLEUM                         0
#
#    ESTIMATED VALUE OF PROPERTY LOST  ESTIMATED VALUE OF PROPERTY SAVED
# 0                           5000000                           20000000
# 1                           1500000                           20000000
# 2                           6000000                           20000000
# 3                                 0                           10000000
# 4                                 0                                  0

# %%
columns = ["year", "causes", "no_of_fire_incidents", "est_value_of_property_lost", "est_value_of_property_saved"]
new_df = pd.DataFrame(columns=columns)

for i, df in enumerate(dfs):
    year = years[i]
    for index, row in df.iterrows():
        transformed_data = [{
            'year': year,
            'causes': row['CAUSE OF FIRE INCIDENCE'],
            'no_of_fire_incidents': row['NUMBER OF FIRE INCIDENTS'],
            'est_value_of_property_lost': row['ESTIMATED VALUE OF PROPERTY LOST'],
            'est_value_of_property_saved': row['ESTIMATED VALUE OF PROPERTY SAVED'],
        },]   

        new_df = pd.concat([new_df, pd.DataFrame(transformed_data)], ignore_index=True)


new_df.head(22)
# Out:
#     year                        causes no_of_fire_incidents  \
# 0   2022          ELECTRICAL EQUIPMENT                    1
# 1   2022                        CANDLE                    1
# 2   2022        HIGH VOLTAGE FROM EEDC                    1
# 3   2022               CIGARETTE STUBS                    1
# 4   2022  ILLEGAL STORAGE OF PETROLEUM                    0
# 5   2022              ELECTRICAL SPARK                   31
# 6   2022             LEAKAGE FROM TANK                    4
# 7   2022     MECHANICAL FAULT ACCIDENT                   22
# 8   2022           UNDER INVESTIGATION                    0
# 9   2022                     EXPLOSION                    2
# 10  2022                       UNKNOWN                   37
# 11  2022                  BUSH BURNING                   21
# 12  2022                           GAS                    4
# 13  2022                         ARSON                    1
# 14  2022                  CARELESSNESS                   10
#
#    est_value_of_property_lost est_value_of_property_saved
# 0                     5000000                    20000000
# 1                     1500000                    20000000
# 2                     6000000                    20000000
# 3                           0                    10000000
# 4                           0                           0
# 5                   470920000                  6393000000
# 6                     4500000                   470000000
# 7                   408300000                  5710500000
# 8                           0                           0
# 9                   100200000                  2500000000
# 10                 1082500000                 57631000000
# 11                  217400000                  3595000000
# 12                    4000000                   665000000
# 13                 2500000000                 20000000000
# 14                  106330000                  2035000000

# %%
new_df.to_excel("fire_incidents_by_causes.xlsx", index=False)
print("Done!")
# Out:
# Done!
